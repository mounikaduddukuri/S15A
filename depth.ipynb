# %% [markdown]
# <a href="https://colab.research.google.com/github/DrVenkataRajeshKumar/S15-A/blob/master/depth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/My Drive/road n car/'
# Out:
# /content/gdrive/My Drive/road n car

# %%
# !unzip fg_bg.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fg_bg/bg_038/fg_014_bg_038_154801.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154802.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154803.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154804.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154805.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154806.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154807.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154808.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154809.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154810.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154811.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154812.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154813.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154814.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154815.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154816.jpg
#   inflating: fg_bg/bg_038/fg_014_bg_038_154817.jpg
# ...

# %%
# !git clone https://github.com/nianticlabs/monodepth2.git
# Out:
# fatal: destination path 'monodepth2' already exists and is not an empty directory.

# %%
cd monodepth2/
# Out:
# /content/gdrive/My Drive/road n car/monodepth2

# %%
# !python test_simple.py --image_path '/content/gdrive/My Drive/road n car/fg_bg/bg_000/'  --model_name mono+stereo_640x192
# Out:
# Streaming output truncated to the last 5000 lines.
#    Processed 2803 of 7800 images - saved prediction to /content/gdrive/My Drive/road n car/fg_bg/bg_000/fg_014_bg_000_002802_disp.jpeg
#    Processed 2804 of 7800 images - saved prediction to /content/gdrive/My Drive/road n car/fg_bg/bg_000/fg_014_bg_000_002803_disp.jpeg
#    Processed 2805 of 7800 images - saved prediction to /content/gdrive/My Drive/road n car/fg_bg/bg_000/fg_014_bg_000_002804_disp.jpeg
#    Processed 2806 of 7800 images - saved prediction to /content/gdrive/My Drive/road n car/fg_bg/bg_000/fg_014_bg_000_002805_disp.jpeg
#    Processed 2807 of 7800 images - saved prediction to /content/gdrive/My Drive/road n car/fg_bg/bg_000/fg_014_bg_000_002806_disp.jpeg
#    Processed 2808 of 7800 images - saved prediction to /content/gdrive/My Drive/road n car/fg_bg/bg_000/fg_014_bg_000_002807_disp.jpeg
# ...
